# %% [markdown]
# # Initial Preprocessing

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Our main data is comprised of 2 datasets:
#
# 1. Drainage basin polygons for each station
# 2. Stream flow data
#
# An additional file is the distances file, which includes, for each hydro station, its five nearest meteorological (rain) stations, ensuring that they were situated within a 10-kilometer radius. The file was given by a student of out professor.

# %%
path_flow1 = '/content/drive/MyDrive/FinalProjectDataScience/flow_in_hydro_stations1.xlsx'
path_flow2 = '/content/drive/MyDrive/FinalProjectDataScience/flow_in_hydro_stations2.xlsx'
path_flow3 = '/content/drive/MyDrive/FinalProjectDataScience/flow_in_hydro_stations3.xlsx'
path_distances = '/content/drive/MyDrive/FinalProjectDataScience/distances.csv'

# %%
df1 = pd.read_excel(path_flow1)
df2 = pd.read_excel(path_flow2)
df3 = pd.read_excel(path_flow3)
df_dist = pd.read_csv(path_distances)

# %%
df_flow1 = df1.copy(deep=True)
df_flow2 = df2.copy(deep=True)
df_flow3 = df3.copy(deep=True)
df_distances = df_dist.copy(deep=True)

# %%
df_distances.head()
# Out:
#    gauge_id  ims_1       dist_1  ims_2       dist_2  ims_3       dist_3  \
# 0     17110     20     0.000000   21.0     0.000000  242.0     0.000000
# 1     17117    242   202.223385   21.0   271.973251  277.0  2730.148982
# 2     17144    259     0.000000  282.0     0.000000  281.0  2793.409143
# 3     17155     24     0.000000  278.0     0.000000  212.0  8992.208041
# 4     17162    270  9037.816647  278.0  9130.979927   54.0  9293.135332
#
#    ims_4       dist_4  ims_5       dist_5
# 0  247.0     0.000000  270.0     0.000000
# 1  278.0  3091.133530   90.0  3354.633013
# 2   24.0  6104.576770  278.0  7264.581355
# 3   54.0  9017.450381  281.0  9078.042992
# 4  212.0  9312.396002    NaN          NaN

# %%
df_flow1.head()
# Out:
#    gauge_id     station_name                time  water_level   flow  \
# 0      2105  כזיב - גשר הזיו 1966-10-01 00:00:00          NaN  0.000
# 1      2105  כזיב - גשר הזיו 1966-12-19 18:35:00         2.88  0.027
# 2      2105  כזיב - גשר הזיו 1966-12-19 18:35:00          NaN  0.027
# 3      2105  כזיב - גשר הזיו 1966-12-19 18:45:00         2.90  0.037
# 4      2105  כזיב - גשר הזיו 1966-12-19 19:00:00         2.90  0.037
#
#   data_type flow_type      row_type  row_type_code
# 0    מדודים      תקין     התחלת קטע              7
# 1    מדודים      גאות     התחלת קטע              7
# 2    מדודים      תקין      סיום קטע              4
# 3    מדודים      גאות  נקודה פנימית              1
# 4    מדודים      גאות  נקודה פנימית              1

# %%
df_flow2.head()
# Out:
#    gauge_id station_name                time  water_level   flow data_type  \
# 0      1102   בצת-כביש 4 2018-01-24 09:17:00         9.97  0.000    מדודים
# 1      1102   בצת-כביש 4 2018-01-24 18:02:00        10.05  0.048    מדודים
# 2      1102   בצת-כביש 4 2018-01-24 22:17:00        10.01  0.024    מדודים
# 3      1102   בצת-כביש 4 2018-01-25 05:32:00        10.12  0.180    מדודים
# 4      1102   בצת-כביש 4 2018-01-25 07:02:00        10.19  0.392    מדודים
#
#   flow_type      row_type  row_type_code
# 0      גאות     התחלת קטע              7
# 1      גאות  נקודה פנימית              1
# 2      גאות  נקודה פנימית              1
# 3      גאות  נקודה פנימית              1
# 4      גאות  נקודה פנימית              1

# %%
df_flow3.head()
# Out:
#    gauge_id     station_name  station_name_english                 time  \
# 0      2105  כזיב - גשר הזיו  KEZIV - HAZIV BRIDGE  03/10/2019 11:11:00
# 1      2105  כזיב - גשר הזיו  KEZIV - HAZIV BRIDGE  03/10/2019 11:11:00
# 2      2105  כזיב - גשר הזיו  KEZIV - HAZIV BRIDGE  31/10/2019 00:00:00
# 3      2105  כזיב - גשר הזיו  KEZIV - HAZIV BRIDGE  01/11/2019 00:00:00
# 4      2105  כזיב - גשר הזיו  KEZIV - HAZIV BRIDGE  28/11/2019 09:17:00
#
#    water_level  flow data_type flow_type      row_type
# 0         2.78   0.0    מדודים      תקין      סיום קטע
# 1         2.78   0.0    מדודים      תקין     התחלת קטע
# 2         2.78   0.0    מדודים      תקין      סיום קטע
# 3         2.78   0.0    מדודים      תקין     התחלת קטע
# 4         2.78   0.0    מדודים      תקין  נקודה פנימית

# %% [markdown]
# ## Delete redundant columns

# %%
redundant_columns_flow_data = ['station_name', 'data_type', 'flow_type', 'row_type']
df_flow1.drop(columns=redundant_columns_flow_data + ['row_type_code'], inplace=True)
df_flow2.drop(columns=redundant_columns_flow_data + ['row_type_code'], inplace=True)
df_flow3.drop(columns=redundant_columns_flow_data + ['station_name_english'], inplace=True)

# %% [markdown]
# ## Combine all flow dataframes into one dataframe

# %%
df_flow = pd.concat([df_flow1, df_flow2, df_flow3])

# %%
len(df_flow['gauge_id'].unique())
# Out:
# 171

# %%
# make the flow feature be the first feature after the keys: gauge_id and time -
# will be conveniant later
df_flow = df_flow[['gauge_id', 'time', 'flow', 'water_level']]

# %%
df_flow.head()
# Out:
#    gauge_id                 time   flow  water_level
# 0      2105  1966-10-01 00:00:00  0.000          NaN
# 1      2105  1966-12-19 18:35:00  0.027         2.88
# 2      2105  1966-12-19 18:35:00  0.027          NaN
# 3      2105  1966-12-19 18:45:00  0.037         2.90
# 4      2105  1966-12-19 19:00:00  0.037         2.90

# %% [markdown]
# ## Include only the stations that appear in the distances table

# %%
df_flow = df_flow[df_flow['gauge_id'].isin(df_distances['gauge_id'])]

# %%
len(df_flow['gauge_id'].unique())
# Out:
# 81

# %%
df_flow[['flow', 'water_level']].describe()
# Out:
#                flow   water_level
# count  1.045921e+06  1.045921e+06
# mean   2.580761e+00  1.524031e+01
# std    9.534524e+00  2.146751e+01
# min    0.000000e+00  0.000000e+00
# 25%    1.100000e-01  9.760000e+00
# 50%    4.620000e-01  1.025000e+01
# 75%    1.370000e+00  1.086000e+01
# max    7.753000e+02  2.258500e+02

# %% [markdown]
# ## Imputation

# %%
df_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045921 entries, 0 to 1045920
# Data columns (total 4 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   gauge_id     1045921 non-null  int64
#  1   time         1045921 non-null  object
#  2   water_level  1034275 non-null  float64
#  3   flow         1045920 non-null  float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 31.9+ MB

# %% [markdown]
# Dealing with null values: just fill with 0.
#
# Another approach: use a test statistic, for example: the mean water level\flow  rate (per station).

# %%
df_flow['water_level'].fillna(0, inplace=True)
df_flow['flow'].fillna(0, inplace=True)

# %%
df_flow['water_level'].isna().sum()
# Out:
# 0

# %%
df_flow['flow'].isna().sum()
# Out:
# 0

# %%
path_flow = '/content/drive/MyDrive/FinalProjectDataScience/flow_in_hydro_stations.xlsx'
df_flow.to_excel(path_flow, index=False)
