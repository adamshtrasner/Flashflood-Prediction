# %% [markdown]
# # Ayalon - Shekhunat 'Ezra Station
# In this notebook we will be looking at Ayalon - Shekhunat 'Ezra station which is near the Ayalon river and in Tel Aviv. This notebook uses data from 2018 to 2021 with the addition of rainfall data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !pip install import-ipynb
import import_ipynb
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from import-ipynb) (7.34.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from import-ipynb) (5.9.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (67.7.2)
# Collecting jedi>=0.16 (from IPython->import-ipynb)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->import-ipynb) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->import-ipynb) (4.19.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from nbformat->import-ipynb) (5.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.10.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.7)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat->import-ipynb) (3.10.0)
# Installing collected packages: jedi, import-ipynb
# Successfully installed import-ipynb-0.1.4 jedi-0.19.1

# %%
from functions import *
# Out:
# importing Jupyter notebook from functions.ipynb
# Collecting scikeras
#   Downloading scikeras-0.11.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras) (23.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.2.0)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.11.0

# %%
# fix random seed for reproducibility
seed = 10
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# Loading the data after preprocessing:

# %%
path_flow = '/content/drive/MyDrive/FinalProjectDataScience/flow_in_hydro_stations.xlsx'
df = pd.read_excel(path_flow)

# %%
df_flow = df.copy(deep=True)

# %%
df_flow.head()
# Out:
#    gauge_id                 time   flow  water_level
# 0      2105  1966-10-01 00:00:00  0.000         0.00
# 1      2105  1966-12-19 18:35:00  0.027         2.88
# 2      2105  1966-12-19 18:35:00  0.027         0.00
# 3      2105  1966-12-19 18:45:00  0.037         2.90
# 4      2105  1966-12-19 19:00:00  0.037         2.90

# %%
path_catalog = '/content/drive/MyDrive/FinalProjectDataScience/hydro_stations_catalog.xlsx'
df_catalog = pd.read_excel(path_catalog)

# %%
df_catalog.head()
# Out:
#    זיהוי תחנה                שם עברית               שם אנגלית שם קודם  \
# 0        1102              בצת-כביש 4           BEZET- ROAD 4   כרכרה
# 1        1105        בצת - ע''י אילון    BEZET - NEAR AYYALON     NaN
# 2        1106  בצת - ע''י חורבת כרכרה    BEZET - NEAR AYYALON     NaN
# 3        2105         כזיב - גשר הזיו    KEZIV - HAZIV BRIDGE    כביר
# 4        2106        כזיב - גשר הרכבת  KEZIV - RAILWAY BRIDGE    כביר
#
#    תאריך הקמה  שטח היקוות (קמר)    X .נ.צ    Y .נ.צ  קשר עם תחנה קודמת  \
# 0  27/01/2015             102.0  211086.0  775565.0                NaN
# 1  01/10/1949              71.0  221150.0  775650.0                NaN
# 2  01/10/1944              71.0  220950.0  775350.0                NaN
# 3  01/10/1966             130.0  210315.0  772922.0                NaN
# 4  01/10/1944             131.0  210100.0  772800.0             2105.0
#
#   תחום התנקזות ראשי סטטוס תחנה
# 0               בצת   לא פעילה
# 1               בצת   לא פעילה
# 2               בצת   לא פעילה
# 3              כזיב      פעילה
# 4              כזיב   לא פעילה

# %% [markdown]
# # Pipeline

# %% [markdown]
# Our approach is to build a different LSTM model for each station.
#
# Since running a model for each station is computationaly heavy, we will choose specific stations that are of interest, and run the model on them only.
#
# The pipeline is:
#
# 1. Run a basic LSTM model on a specific gauge - without additional data.
# 2. Run an LSTM model with the addition of the rainfall data.
# 3. Compare between the 2 models.
# 4. Run hyperparameter optimization on the LSTM model with the rainfall data.
# 5. Run LSTM model after optimization.
# 6. Run a GRU model with the rainfall data.
# 7. Run hyperparameter optimization on the GRU model with the rainfall data.
# 8. Compare results between LSTM and GRU.

# %% [markdown]
# ## Hyperparameters

# %%
# Time Resolution
time_resolution = '10T'

# Number of sequences in the data per hour (depends on time resolution)
sequences_per_hour = 6

# Lead time (by hours)
l = 3

# Number of epochs
epochs = 5

# Batch size
batch_size = 128

# Number of years to train over
n_train_years = 3

# size of validation set
validation_split = 0.333

# %% [markdown]
# ## Preprocess

# %%
gauge_id = 17168
gauge_name = df_catalog[df_catalog['זיהוי תחנה'] == gauge_id]['שם אנגלית'].iloc[0]

# %%
gauge_df = get_data_of_gauge(gauge_id)
gauge_df.drop(columns=['gauge_id'], inplace=True)
# Out:
# <ipython-input-109-2081e5c32cd2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gauge_df.drop(columns=['gauge_id'], inplace=True)

# %%
# Set 'timestamp' as the DataFrame index
gauge_df['time'] = pd.to_datetime(gauge_df['time'])
# Out:
# <ipython-input-110-cfd5998e3239>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gauge_df['time'] = pd.to_datetime(gauge_df['time'])

# %%
gauge_df = gauge_df[(gauge_df['time'].dt.year >= START_YEAR) & (gauge_df['time'].dt.year <= END_YEAR)]

# %%
gauge_df = resample_data(gauge_df, time_resolution)

# %%
gauge_df
# Out:
#                       flow  water_level
# time
# 2018-01-01 00:00:00  0.058        12.36
# 2018-01-01 00:10:00  0.058        12.36
# 2018-01-01 00:20:00  0.058        12.36
# 2018-01-01 00:30:00  0.058        12.36
# 2018-01-01 00:40:00  0.058        12.36
# ...                    ...          ...
# 2021-12-04 19:40:00  0.013        11.87
# 2021-12-04 19:50:00  0.013        11.87
# 2021-12-04 20:00:00  0.013        11.87
# 2021-12-04 20:10:00  0.013        11.87
# 2021-12-04 20:20:00  0.013        11.87
#
# [206475 rows x 2 columns]

# %%
# prepare loss function
std = gauge_df['flow'].std()
nse_star = get_nse_loss(std)

# %%
# prepare nse metric
mean = gauge_df['flow'].mean()
nse_tensor = get_nse_tensor(mean)
nse_numpy = get_nse_numpy(mean)

# %% [markdown]
# ## Choice of Lead Time

# %%
nse_means = {1:0, 2:0, 3:0}
persist_nse_means = {1:0, 2:0, 3:0}
n_iter = 3

for i in range(n_iter):
  for lead_time in range(1, 4):
    # number of lag hours
    n_hours = lead_time * sequences_per_hour
    reframed, scaler = prepare_data(gauge_df, n_hours)

    # number of total features
    n_features = len(gauge_df.columns)

    # drop columns of reframed that are not for prediction
    n_cols_reframed = len(reframed.columns)
    reframed.drop(reframed.columns[n_cols_reframed-n_features+1:], axis=1, inplace=True)

    # split into train and test sets
    n_train_sequences = num_months_train * DAYS_PER_MONTH * HOURS_PER_DAY * sequences_per_hour
    train_X, train_y, test_X, test_y = split_train_and_test(reframed, n_train_sequences, n_hours, n_features)

    # prepare creating model
    metrics = [persistent_nse_tensor, nse_tensor]
    create_model = build_model(train_X, nse_star, metrics, LSTM)

    # run model
    model = create_model()
    history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, validation_split=validation_split, verbose=2, shuffle=False)

    # make a prediction
    yhat = model.predict(test_X)
    test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))

    # invert scaling for forecast
    inv_yhat = np.concatenate((yhat, test_X[:, -(n_features-1):]), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:,0]

    # invert scaling for actual
    test_y = test_y.reshape((len(test_y), 1))
    inv_y = np.concatenate((test_y, test_X[:, -(n_features-1):]), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,0]

    # calculate NSE
    nse_numpy = get_nse_numpy(mean)
    nse_metric = nse_numpy(inv_y, inv_yhat)
    nse_means[lead_time] += nse_metric/n_iter

    # calculate persistNSE
    persist_nse_metric = persistent_nse_numpy(inv_y, inv_yhat)
    persist_nse_means[lead_time] += persist_nse_metric/n_iter
# Out:
# Epoch 1/5
# 861/861 - 5s - loss: 0.0012 - persistent_nse_tensor: 0.4259 - nse_tensor: 0.9999 - val_loss: 0.0020 - val_persistent_nse_tensor: -3.0999e-01 - val_nse_tensor: 0.9998 - 5s/epoch - 6ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 1.9126e-04 - persistent_nse_tensor: 0.9329 - nse_tensor: 1.0000 - val_loss: 9.8010e-05 - val_persistent_nse_tensor: 0.9518 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 3s - loss: 2.5989e-04 - persistent_nse_tensor: 0.9165 - nse_tensor: 1.0000 - val_loss: 0.0028 - val_persistent_nse_tensor: -8.3551e-01 - val_nse_tensor: 0.9997 - 3s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 3.3852e-04 - persistent_nse_tensor: 0.8815 - nse_tensor: 1.0000 - val_loss: 6.8101e-05 - val_persistent_nse_tensor: 0.9666 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 1.0708e-04 - persistent_nse_tensor: 0.9755 - nse_tensor: 1.0000 - val_loss: 9.4354e-05 - val_persistent_nse_tensor: 0.9445 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1291/1291 [==============================] - 2s 2ms/step
# Epoch 1/5
# 861/861 - 6s - loss: 8.8212e-04 - persistent_nse_tensor: 0.6213 - nse_tensor: 0.9999 - val_loss: 1.6415e-04 - val_persistent_nse_tensor: 0.9253 - val_nse_tensor: 1.0000 - 6s/epoch - 7ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 1.3737e-04 - persistent_nse_tensor: 0.9570 - nse_tensor: 1.0000 - val_loss: 3.0632e-04 - val_persistent_nse_tensor: 0.7791 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 3s - loss: 1.0464e-04 - persistent_nse_tensor: 0.9695 - nse_tensor: 1.0000 - val_loss: 1.5052e-04 - val_persistent_nse_tensor: 0.8991 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 1.3016e-04 - persistent_nse_tensor: 0.9641 - nse_tensor: 1.0000 - val_loss: 2.7352e-04 - val_persistent_nse_tensor: 0.8201 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 9.6615e-05 - persistent_nse_tensor: 0.9785 - nse_tensor: 1.0000 - val_loss: 1.1753e-04 - val_persistent_nse_tensor: 0.9365 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1291/1291 [==============================] - 2s 2ms/step
# Epoch 1/5
# 861/861 - 6s - loss: 0.0012 - persistent_nse_tensor: 0.5515 - nse_tensor: 0.9999 - val_loss: 0.0011 - val_persistent_nse_tensor: 0.3840 - val_nse_tensor: 0.9999 - 6s/epoch - 6ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 2.1602e-04 - persistent_nse_tensor: 0.9226 - nse_tensor: 1.0000 - val_loss: 2.2467e-04 - val_persistent_nse_tensor: 0.8789 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 3s - loss: 3.0703e-04 - persistent_nse_tensor: 0.9062 - nse_tensor: 1.0000 - val_loss: 0.0028 - val_persistent_nse_tensor: -6.6801e-01 - val_nse_tensor: 0.9997 - 3s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 4.0330e-04 - persistent_nse_tensor: 0.8793 - nse_tensor: 1.0000 - val_loss: 7.0264e-05 - val_persistent_nse_tensor: 0.9686 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 9.8548e-05 - persistent_nse_tensor: 0.9790 - nse_tensor: 1.0000 - val_loss: 9.7114e-05 - val_persistent_nse_tensor: 0.9406 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1290/1290 [==============================] - 3s 2ms/step
# Epoch 1/5
# 861/861 - 6s - loss: 0.0011 - persistent_nse_tensor: 0.4696 - nse_tensor: 0.9999 - val_loss: 0.0011 - val_persistent_nse_tensor: 0.2223 - val_nse_tensor: 0.9999 - 6s/epoch - 7ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 1.0449e-04 - persistent_nse_tensor: 0.9726 - nse_tensor: 1.0000 - val_loss: 4.3665e-05 - val_persistent_nse_tensor: 0.9821 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 3s - loss: 1.5274e-04 - persistent_nse_tensor: 0.9519 - nse_tensor: 1.0000 - val_loss: 5.5517e-04 - val_persistent_nse_tensor: 0.5576 - val_nse_tensor: 0.9999 - 3s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 1.7705e-04 - persistent_nse_tensor: 0.9371 - nse_tensor: 1.0000 - val_loss: 6.5897e-05 - val_persistent_nse_tensor: 0.9657 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 9.9731e-05 - persistent_nse_tensor: 0.9746 - nse_tensor: 1.0000 - val_loss: 2.0226e-04 - val_persistent_nse_tensor: 0.8480 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1291/1291 [==============================] - 2s 2ms/step
# Epoch 1/5
# 861/861 - 6s - loss: 8.7225e-04 - persistent_nse_tensor: 0.5858 - nse_tensor: 0.9999 - val_loss: 7.5172e-04 - val_persistent_nse_tensor: 0.5407 - val_nse_tensor: 0.9999 - 6s/epoch - 7ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 1.0698e-04 - persistent_nse_tensor: 0.9682 - nse_tensor: 1.0000 - val_loss: 9.2475e-05 - val_persistent_nse_tensor: 0.9609 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 3s - loss: 1.6883e-04 - persistent_nse_tensor: 0.9373 - nse_tensor: 1.0000 - val_loss: 6.2096e-04 - val_persistent_nse_tensor: 0.5494 - val_nse_tensor: 0.9999 - 3s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 1.9909e-04 - persistent_nse_tensor: 0.9319 - nse_tensor: 1.0000 - val_loss: 5.0126e-05 - val_persistent_nse_tensor: 0.9784 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 1.1739e-04 - persistent_nse_tensor: 0.9649 - nse_tensor: 1.0000 - val_loss: 3.8299e-04 - val_persistent_nse_tensor: 0.6959 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1291/1291 [==============================] - 2s 2ms/step
# Epoch 1/5
# 861/861 - 6s - loss: 7.1006e-04 - persistent_nse_tensor: 0.6740 - nse_tensor: 0.9999 - val_loss: 1.8661e-04 - val_persistent_nse_tensor: 0.9135 - val_nse_tensor: 1.0000 - 6s/epoch - 7ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 1.0183e-04 - persistent_nse_tensor: 0.9719 - nse_tensor: 1.0000 - val_loss: 8.1719e-05 - val_persistent_nse_tensor: 0.9583 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 3s - loss: 1.0592e-04 - persistent_nse_tensor: 0.9701 - nse_tensor: 1.0000 - val_loss: 1.0578e-04 - val_persistent_nse_tensor: 0.9636 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 1.1246e-04 - persistent_nse_tensor: 0.9689 - nse_tensor: 1.0000 - val_loss: 1.3519e-04 - val_persistent_nse_tensor: 0.9243 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 8.2286e-05 - persistent_nse_tensor: 0.9806 - nse_tensor: 1.0000 - val_loss: 5.5542e-05 - val_persistent_nse_tensor: 0.9857 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1290/1290 [==============================] - 3s 2ms/step
# Epoch 1/5
# 861/861 - 5s - loss: 0.0011 - persistent_nse_tensor: 0.4306 - nse_tensor: 0.9999 - val_loss: 0.0020 - val_persistent_nse_tensor: -4.0876e-01 - val_nse_tensor: 0.9998 - 5s/epoch - 6ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 1.7834e-04 - persistent_nse_tensor: 0.9359 - nse_tensor: 1.0000 - val_loss: 8.8742e-05 - val_persistent_nse_tensor: 0.9592 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 3s - loss: 2.8351e-04 - persistent_nse_tensor: 0.9065 - nse_tensor: 1.0000 - val_loss: 0.0031 - val_persistent_nse_tensor: -1.0065e+00 - val_nse_tensor: 0.9997 - 3s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 3.7873e-04 - persistent_nse_tensor: 0.8633 - nse_tensor: 1.0000 - val_loss: 7.1126e-05 - val_persistent_nse_tensor: 0.9634 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 1.0929e-04 - persistent_nse_tensor: 0.9750 - nse_tensor: 1.0000 - val_loss: 9.7766e-05 - val_persistent_nse_tensor: 0.9435 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1291/1291 [==============================] - 2s 2ms/step
# Epoch 1/5
# 861/861 - 6s - loss: 8.9035e-04 - persistent_nse_tensor: 0.6155 - nse_tensor: 0.9999 - val_loss: 1.1245e-04 - val_persistent_nse_tensor: 0.9514 - val_nse_tensor: 1.0000 - 6s/epoch - 7ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 1.4374e-04 - persistent_nse_tensor: 0.9554 - nse_tensor: 1.0000 - val_loss: 3.0713e-04 - val_persistent_nse_tensor: 0.7898 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 3s - loss: 1.3273e-04 - persistent_nse_tensor: 0.9550 - nse_tensor: 1.0000 - val_loss: 1.1034e-04 - val_persistent_nse_tensor: 0.9291 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 1.3522e-04 - persistent_nse_tensor: 0.9627 - nse_tensor: 1.0000 - val_loss: 3.6065e-04 - val_persistent_nse_tensor: 0.7205 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 8.8284e-05 - persistent_nse_tensor: 0.9829 - nse_tensor: 1.0000 - val_loss: 9.2068e-05 - val_persistent_nse_tensor: 0.9533 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1291/1291 [==============================] - 3s 2ms/step
# Epoch 1/5
# 861/861 - 6s - loss: 8.1058e-04 - persistent_nse_tensor: 0.6527 - nse_tensor: 0.9999 - val_loss: 1.2294e-04 - val_persistent_nse_tensor: 0.9405 - val_nse_tensor: 1.0000 - 6s/epoch - 6ms/step
# Epoch 2/5
# 861/861 - 3s - loss: 1.4281e-04 - persistent_nse_tensor: 0.9546 - nse_tensor: 1.0000 - val_loss: 3.5104e-04 - val_persistent_nse_tensor: 0.7175 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 861/861 - 4s - loss: 8.4471e-05 - persistent_nse_tensor: 0.9832 - nse_tensor: 1.0000 - val_loss: 3.4803e-05 - val_persistent_nse_tensor: 0.9952 - val_nse_tensor: 1.0000 - 4s/epoch - 4ms/step
# Epoch 4/5
# 861/861 - 3s - loss: 1.1212e-04 - persistent_nse_tensor: 0.9712 - nse_tensor: 1.0000 - val_loss: 1.9512e-04 - val_persistent_nse_tensor: 0.9249 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 861/861 - 3s - loss: 1.1250e-04 - persistent_nse_tensor: 0.9708 - nse_tensor: 1.0000 - val_loss: 9.4224e-05 - val_persistent_nse_tensor: 0.9332 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# 1290/1290 [==============================] - 3s 2ms/step

# %%
nse_means
# Out:
# {1: 0.3918605902897182, 2: 0.0036158850864210224, 3: 0.6808690657990486}

# %%
persist_nse_means
# Out:
# {1: -2.9261475791737177, 2: -5.4642462686223805, 3: -1.0805800915476413}

# %% [markdown]
# We can see that the best choice for lead time by both mean scores is 3 hours.

# %% [markdown]
# ## LSTM model without rainfall data

# %%
# number of lag hours
n_hours = l * sequences_per_hour
reframed, scaler = prepare_data(gauge_df, n_hours)

# number of total features
n_features = len(gauge_df.columns)

# drop columns of reframed that are not for prediction
n_cols_reframed = len(reframed.columns)
reframed.drop(reframed.columns[n_cols_reframed-n_features+1:], axis=1, inplace=True)

print(reframed.head())

# split into train and test sets
n_train_sequences = n_train_years * DAYS_PER_YEAR * HOURS_PER_DAY * sequences_per_hour
train_X, train_y, test_X, test_y = split_train_and_test(reframed, n_train_sequences, n_hours, n_features)
# Out:
#     var1(t-18)  var2(t-18)  var1(t-17)  var2(t-17)  var1(t-16)  var2(t-16)  \
# 18    0.000244    0.757353    0.000244    0.757353    0.000244    0.757353
# 19    0.000244    0.757353    0.000244    0.757353    0.000244    0.757353
# 20    0.000244    0.757353    0.000244    0.757353    0.000244    0.757353
# 21    0.000244    0.757353    0.000244    0.757353    0.000244    0.757353
# 22    0.000244    0.757353    0.000244    0.757353    0.000244    0.757353
#
#     var1(t-15)  var2(t-15)  var1(t-14)  var2(t-14)  ...  var2(t-5)  var1(t-4)  \
# 18    0.000244    0.757353    0.000244    0.757353  ...   0.757353   0.000244
# 19    0.000244    0.757353    0.000244    0.757353  ...   0.757353   0.000307
# 20    0.000244    0.757353    0.000244    0.757353  ...   0.757598   0.000370
# 21    0.000244    0.757353    0.000244    0.757353  ...   0.757843   0.000433
# 22    0.000244    0.757353    0.000244    0.757353  ...   0.758088   0.000496
#
#     var2(t-4)  var1(t-3)  var2(t-3)  var1(t-2)  var2(t-2)  var1(t-1)  \
# 18   0.757353   0.000307   0.757598   0.000370   0.757843   0.000433
# 19   0.757598   0.000370   0.757843   0.000433   0.758088   0.000496
# 20   0.757843   0.000433   0.758088   0.000496   0.758333   0.000559
# 21   0.758088   0.000496   0.758333   0.000559   0.758578   0.000621
# 22   0.758333   0.000559   0.758578   0.000621   0.758824   0.000684
#
#     var2(t-1)   var1(t)
# 18   0.758088  0.000496
# 19   0.758333  0.000559
# 20   0.758578  0.000621
# 21   0.758824  0.000684
# 22   0.759069  0.000747
#
# [5 rows x 37 columns]

# %%
# prepare creating model
metrics = [persistent_nse_tensor, nse_tensor]
create_model = build_model(train_X, nse_star, metrics, LSTM)

# run model
model = create_model()
history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, validation_split=validation_split, verbose=2, shuffle=False)
# Out:
# Epoch 1/5
# 822/822 - 6s - loss: 7.4988e-04 - persistent_nse_tensor: 0.6905 - nse_tensor: 0.9999 - val_loss: 2.6355e-04 - val_persistent_nse_tensor: 0.8609 - val_nse_tensor: 1.0000 - 6s/epoch - 7ms/step
# Epoch 2/5
# 822/822 - 3s - loss: 1.0554e-04 - persistent_nse_tensor: 0.9697 - nse_tensor: 1.0000 - val_loss: 2.9140e-04 - val_persistent_nse_tensor: 0.8614 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 822/822 - 3s - loss: 8.5695e-05 - persistent_nse_tensor: 0.9822 - nse_tensor: 1.0000 - val_loss: 6.5847e-05 - val_persistent_nse_tensor: 0.9723 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 4/5
# 822/822 - 3s - loss: 8.6983e-05 - persistent_nse_tensor: 0.9797 - nse_tensor: 1.0000 - val_loss: 1.4879e-04 - val_persistent_nse_tensor: 0.9303 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 822/822 - 3s - loss: 8.7094e-05 - persistent_nse_tensor: 0.9791 - nse_tensor: 1.0000 - val_loss: 1.7935e-04 - val_persistent_nse_tensor: 0.9107 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step

# %%
plot_history(epochs, history, gauge_name)

# %%
time_test = list(gauge_df.reset_index(inplace=False).iloc[n_train_sequences+n_hours:, 0].astype('str'))
plot_predicted_vs_observed(model, scaler, test_X, test_y, n_hours, n_features, mean, time_test, gauge_name)
# Out:
# 1525/1525 [==============================] - 3s 2ms/step
# Test NSE: 0.957
# Test PersistentNSE: 0.957

# %%
persist_nse_without_precipitation = history.history['val_persistent_nse_tensor']

# %%
plt.plot(persist_nse_without_precipitation, c='green')
plt.title('LSTM without precipitation')
plt.xticks(np.arange(epochs), np.arange(1, epochs+1))
plt.xlabel('epoch')
plt.ylabel('persistNSE')
plt.show()

# %% [markdown]
# ## LSTM model with rainfall data

# %% [markdown]
# ### Rainfall data from 3 closest rain stations

# %%
ims_stations = [40545, 40550, 40654]

# %%
dfs_stations = []
for i, ims_id in enumerate(ims_stations):

  dfs_rain = []
  for year in range(START_YEAR, END_YEAR+1):
    rain_path = f'/content/drive/MyDrive/FinalProjectDataScience/IMS/gauge_{gauge_id}/{year}/{ims_id}_.txt'
    df_rain = pd.read_csv(rain_path, delimiter=',')
    df_rain.rename(columns={'Date_Time[]': 'time', 'Rain[mm]': f'rain[mm]_ims_{i+1}'}, inplace=True)

    # impute -999.0 (null) values to zero
    df_rain[f'rain[mm]_ims_{i+1}'] = df_rain[f'rain[mm]_ims_{i+1}'].apply(lambda x: 0 if x == -999.0 else x)
    dfs_rain.append(df_rain)

  df_merged_rain = pd.concat(dfs_rain, ignore_index=True)
  df_merged_rain['time'] = pd.to_datetime(df_merged_rain['time'])
  dfs_stations.append(df_merged_rain)

# %%
# time resolution of rain data is 10 minutes by default
if time_resolution != '10T':
  for i in range(len(dfs_stations)):
    dfs_stations[i] = resample_data(dfs_stations[i], time_resolution)
    dfs_stations[i].reset_index(inplace=True)

# %%
gauge_df.reset_index(inplace=True)

# %%
df_flow_rain_merged = gauge_df.copy(deep=True)
for df in dfs_stations:
  df_flow_rain_merged = pd.merge(df_flow_rain_merged, df, on='time')

# %%
gauge_df.set_index('time', inplace=True)

# %%
df_flow_rain_merged.set_index('time', inplace=True)

# %%
df_flow_rain_merged
# Out:
#                       flow  water_level  rain[mm]_ims_1  rain[mm]_ims_2  \
# time
# 2018-01-01 00:00:00  0.058        12.36             0.0             0.0
# 2018-01-01 00:10:00  0.058        12.36             0.0             0.0
# 2018-01-01 00:20:00  0.058        12.36             0.0             0.0
# 2018-01-01 00:30:00  0.058        12.36             0.0             0.0
# 2018-01-01 00:40:00  0.058        12.36             0.0             0.0
# ...                    ...          ...             ...             ...
# 2021-12-04 19:40:00  0.013        11.87             0.0             0.0
# 2021-12-04 19:50:00  0.013        11.87             0.0             0.0
# 2021-12-04 20:00:00  0.013        11.87             0.0             0.0
# 2021-12-04 20:10:00  0.013        11.87             0.0             0.0
# 2021-12-04 20:20:00  0.013        11.87             0.0             0.0
#
#                      rain[mm]_ims_3
# time
# 2018-01-01 00:00:00             0.0
# 2018-01-01 00:10:00             0.0
# 2018-01-01 00:20:00             0.0
# 2018-01-01 00:30:00             0.0
# 2018-01-01 00:40:00             0.0
# ...                             ...
# 2021-12-04 19:40:00             0.0
# 2021-12-04 19:50:00             0.0
# 2021-12-04 20:00:00             0.0
# 2021-12-04 20:10:00             0.0
# 2021-12-04 20:20:00             0.0
#
# [206496 rows x 5 columns]

# %% [markdown]
# ### Training and Validation

# %%
# number of lag hours
n_hours = l * sequences_per_hour
reframed, scaler = prepare_data(df_flow_rain_merged, n_hours)

# number of total features
n_features = len(df_flow_rain_merged.columns)

# drop columns of reframed that are not for prediction
n_cols_reframed = len(reframed.columns)
reframed.drop(reframed.columns[n_cols_reframed-n_features+1:], axis=1, inplace=True)

print(reframed.head())

# split into train and test sets
n_train_sequences = n_train_years * DAYS_PER_YEAR * HOURS_PER_DAY * sequences_per_hour
train_X, train_y, test_X, test_y = split_train_and_test(reframed, n_train_sequences, n_hours, n_features)
# Out:
#     var1(t-18)  var2(t-18)  var3(t-18)  var4(t-18)  var5(t-18)  var1(t-17)  \
# 18    0.000244    0.757353         0.0         0.0         0.0    0.000244
# 19    0.000244    0.757353         0.0         0.0         0.0    0.000244
# 20    0.000244    0.757353         0.0         0.0         0.0    0.000244
# 21    0.000244    0.757353         0.0         0.0         0.0    0.000244
# 22    0.000244    0.757353         0.0         0.0         0.0    0.000244
#
#     var2(t-17)  var3(t-17)  var4(t-17)  var5(t-17)  ...  var2(t-2)  var3(t-2)  \
# 18    0.757353         0.0         0.0         0.0  ...   0.757843   0.000000
# 19    0.757353         0.0         0.0         0.0  ...   0.758088   0.000000
# 20    0.757353         0.0         0.0         0.0  ...   0.758333   0.000000
# 21    0.757353         0.0         0.0         0.0  ...   0.758578   0.000000
# 22    0.757353         0.0         0.0         0.0  ...   0.758824   0.016393
#
#     var4(t-2)  var5(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  \
# 18        0.0        0.0   0.000433   0.758088   0.000000        0.0
# 19        0.0        0.0   0.000496   0.758333   0.000000        0.0
# 20        0.0        0.0   0.000559   0.758578   0.000000        0.0
# 21        0.0        0.0   0.000621   0.758824   0.016393        0.0
# 22        0.0        0.0   0.000684   0.759069   0.008197        0.0
#
#     var5(t-1)   var1(t)
# 18        0.0  0.000496
# 19        0.0  0.000559
# 20        0.0  0.000621
# 21        0.0  0.000684
# 22        0.0  0.000747
#
# [5 rows x 91 columns]

# %%
# prepare creating model
metrics = [persistent_nse_tensor, nse_tensor]
create_model = build_model(train_X, nse_star, metrics, LSTM)

# run model
model = create_model()
history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, validation_split=validation_split, verbose=2, shuffle=False)
# Out:
# Epoch 1/5
# 822/822 - 6s - loss: 5.9975e-04 - persistent_nse_tensor: 0.7304 - nse_tensor: 0.9999 - val_loss: 2.7359e-04 - val_persistent_nse_tensor: 0.8668 - val_nse_tensor: 1.0000 - 6s/epoch - 7ms/step
# Epoch 2/5
# 822/822 - 3s - loss: 1.1167e-04 - persistent_nse_tensor: 0.9714 - nse_tensor: 1.0000 - val_loss: 5.4863e-04 - val_persistent_nse_tensor: 0.7423 - val_nse_tensor: 0.9999 - 3s/epoch - 4ms/step
# Epoch 3/5
# 822/822 - 4s - loss: 1.8243e-04 - persistent_nse_tensor: 0.9373 - nse_tensor: 1.0000 - val_loss: 1.3600e-04 - val_persistent_nse_tensor: 0.9334 - val_nse_tensor: 1.0000 - 4s/epoch - 4ms/step
# Epoch 4/5
# 822/822 - 3s - loss: 1.2770e-04 - persistent_nse_tensor: 0.9653 - nse_tensor: 1.0000 - val_loss: 7.7842e-04 - val_persistent_nse_tensor: 0.6381 - val_nse_tensor: 0.9999 - 3s/epoch - 4ms/step
# Epoch 5/5
# 822/822 - 3s - loss: 1.8593e-04 - persistent_nse_tensor: 0.9433 - nse_tensor: 1.0000 - val_loss: 1.3641e-04 - val_persistent_nse_tensor: 0.9333 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step

# %%
plot_history(epochs, history, gauge_name)

# %%
time_test = list(df_flow_rain_merged.reset_index(inplace=False).iloc[n_train_sequences+n_hours:, 0].astype('str'))
plot_predicted_vs_observed(model, scaler, test_X, test_y, n_hours, n_features, mean, time_test, gauge_name)
# Out:
# 1525/1525 [==============================] - 3s 2ms/step
# Test NSE: 0.975
# Test PersistentNSE: 0.975

# %%
persist_nse_with_precipitation_lstm = history.history['val_persistent_nse_tensor']

# %%
plt.plot(persist_nse_with_precipitation_lstm, c='green')
plt.title('LSTM with precipitation')
plt.xticks(np.arange(epochs), np.arange(1, epochs+1))
plt.xlabel('epoch')
plt.ylabel('persistNSE')
plt.show()

# %% [markdown]
# ### Hyperparameter Optimization

# %%
model = KerasRegressor(build_fn=create_model, n_neurons=128)

# %%
from keras.src.layers.serialization import activation
param_grid = dict(epochs=[5, 10, 15], batch_size=[32, 64, 128], n_neurons=[64, 128])
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=make_scorer(persistent_nse_numpy), n_jobs=-1, cv=3, verbose=2)
grid_result = grid.fit(train_X, train_y)
print("Done grid search")
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Epoch 1/15
# 1232/1232 [==============================] - 7s 4ms/step - loss: 3.3260e-04 - persistent_nse_tensor: 0.9100 - nse_tensor: 1.0000
# Epoch 2/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 1.1127e-04 - persistent_nse_tensor: 0.9723 - nse_tensor: 1.0000
# Epoch 3/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 1.1205e-04 - persistent_nse_tensor: 0.9735 - nse_tensor: 1.0000
# Epoch 4/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 1.0851e-04 - persistent_nse_tensor: 0.9739 - nse_tensor: 1.0000
# Epoch 5/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 1.0197e-04 - persistent_nse_tensor: 0.9753 - nse_tensor: 1.0000
# Epoch 6/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 9.2038e-05 - persistent_nse_tensor: 0.9770 - nse_tensor: 1.0000
# Epoch 7/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 7.0949e-05 - persistent_nse_tensor: 0.9812 - nse_tensor: 1.0000
# Epoch 8/15
# 1232/1232 [==============================] - 4s 4ms/step - loss: 5.5670e-05 - persistent_nse_tensor: 0.9848 - nse_tensor: 1.0000
# Epoch 9/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 4.4784e-05 - persistent_nse_tensor: 0.9874 - nse_tensor: 1.0000
# Epoch 10/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 3.3529e-05 - persistent_nse_tensor: 0.9903 - nse_tensor: 1.0000
# Epoch 11/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 2.7109e-05 - persistent_nse_tensor: 0.9921 - nse_tensor: 1.0000
# Epoch 12/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 2.3033e-05 - persistent_nse_tensor: 0.9932 - nse_tensor: 1.0000
# Epoch 13/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 2.0900e-05 - persistent_nse_tensor: 0.9940 - nse_tensor: 1.0000
# Epoch 14/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 1.7787e-05 - persistent_nse_tensor: 0.9947 - nse_tensor: 1.0000
# Epoch 15/15
# 1232/1232 [==============================] - 5s 4ms/step - loss: 1.5701e-05 - persistent_nse_tensor: 0.9953 - nse_tensor: 1.0000
# Done grid search

# %%
print("Best: test score %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for m, s, param in zip(means, stds, params):
    print("mean test score %f (std test score %f) with: %r" % (m, s, param))
# Out:
# Best: test score 0.978011 using {'batch_size': 128, 'epochs': 15, 'n_neurons': 128}
# mean test score 0.965199 (std test score 0.012921) with: {'batch_size': 32, 'epochs': 5, 'n_neurons': 64}
# mean test score 0.960116 (std test score 0.017634) with: {'batch_size': 32, 'epochs': 5, 'n_neurons': 128}
# mean test score 0.968328 (std test score 0.009507) with: {'batch_size': 32, 'epochs': 10, 'n_neurons': 64}
# mean test score 0.966656 (std test score 0.011013) with: {'batch_size': 32, 'epochs': 10, 'n_neurons': 128}
# mean test score 0.954041 (std test score 0.006688) with: {'batch_size': 32, 'epochs': 15, 'n_neurons': 64}
# mean test score 0.961845 (std test score 0.006257) with: {'batch_size': 32, 'epochs': 15, 'n_neurons': 128}
# mean test score 0.953326 (std test score 0.025247) with: {'batch_size': 64, 'epochs': 5, 'n_neurons': 64}
# mean test score 0.967084 (std test score 0.020708) with: {'batch_size': 64, 'epochs': 5, 'n_neurons': 128}
# mean test score 0.959523 (std test score 0.022099) with: {'batch_size': 64, 'epochs': 10, 'n_neurons': 64}
# mean test score 0.975798 (std test score 0.011062) with: {'batch_size': 64, 'epochs': 10, 'n_neurons': 128}
# mean test score 0.966848 (std test score 0.008976) with: {'batch_size': 64, 'epochs': 15, 'n_neurons': 64}
# mean test score 0.965527 (std test score 0.011770) with: {'batch_size': 64, 'epochs': 15, 'n_neurons': 128}
# mean test score 0.970884 (std test score 0.009086) with: {'batch_size': 128, 'epochs': 5, 'n_neurons': 64}
# mean test score 0.972002 (std test score 0.016944) with: {'batch_size': 128, 'epochs': 5, 'n_neurons': 128}
# mean test score 0.972971 (std test score 0.006843) with: {'batch_size': 128, 'epochs': 10, 'n_neurons': 64}
# mean test score 0.957428 (std test score 0.040821) with: {'batch_size': 128, 'epochs': 10, 'n_neurons': 128}
# mean test score 0.965801 (std test score 0.018815) with: {'batch_size': 128, 'epochs': 15, 'n_neurons': 64}
# mean test score 0.978011 (std test score 0.007285) with: {'batch_size': 128, 'epochs': 15, 'n_neurons': 128}

# %%
def highlight_max_row(data):
    """Highlight the entire row if mean_test_score is the maximum."""
    max_score = data['mean_test_score'].max()
    highlight = ['background-color: yellow' if val == max_score else '' for val in data['mean_test_score']]
    return pd.DataFrame([highlight for _ in data.columns], index=data.columns).T

# %%
df_grid = pd.DataFrame({
    'param_batch_size': grid_result.cv_results_['param_batch_size'].data,
    'param_epochs': grid_result.cv_results_['param_epochs'].data,
    'param_n_neurons': grid_result.cv_results_['param_n_neurons'].data,
    'mean_test_score': grid_result.cv_results_['mean_test_score']
})

df_grid.style.apply(highlight_max_row, axis=None)
# Out:
# <style type="text/css">
# #T_eaecf_row17_col0, #T_eaecf_row17_col1, #T_eaecf_row17_col2, #T_eaecf_row17_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_eaecf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaecf_level0_col0" class="col_heading level0 col0" >param_batch_size</th>
#       <th id="T_eaecf_level0_col1" class="col_heading level0 col1" >param_epochs</th>
#       <th id="T_eaecf_level0_col2" class="col_heading level0 col2" >param_n_neurons</th>
#       <th id="T_eaecf_level0_col3" class="col_heading level0 col3" >mean_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaecf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaecf_row0_col0" class="data row0 col0" >32</td>
#       <td id="T_eaecf_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_eaecf_row0_col2" class="data row0 col2" >64</td>
#       <td id="T_eaecf_row0_col3" class="data row0 col3" >0.965199</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eaecf_row1_col0" class="data row1 col0" >32</td>
#       <td id="T_eaecf_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_eaecf_row1_col2" class="data row1 col2" >128</td>
#       <td id="T_eaecf_row1_col3" class="data row1 col3" >0.960116</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eaecf_row2_col0" class="data row2 col0" >32</td>
#       <td id="T_eaecf_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_eaecf_row2_col2" class="data row2 col2" >64</td>
#       <td id="T_eaecf_row2_col3" class="data row2 col3" >0.968328</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eaecf_row3_col0" class="data row3 col0" >32</td>
#       <td id="T_eaecf_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_eaecf_row3_col2" class="data row3 col2" >128</td>
#       <td id="T_eaecf_row3_col3" class="data row3 col3" >0.966656</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eaecf_row4_col0" class="data row4 col0" >32</td>
#       <td id="T_eaecf_row4_col1" class="data row4 col1" >15</td>
#       <td id="T_eaecf_row4_col2" class="data row4 col2" >64</td>
#       <td id="T_eaecf_row4_col3" class="data row4 col3" >0.954041</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eaecf_row5_col0" class="data row5 col0" >32</td>
#       <td id="T_eaecf_row5_col1" class="data row5 col1" >15</td>
#       <td id="T_eaecf_row5_col2" class="data row5 col2" >128</td>
#       <td id="T_eaecf_row5_col3" class="data row5 col3" >0.961845</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eaecf_row6_col0" class="data row6 col0" >64</td>
#       <td id="T_eaecf_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_eaecf_row6_col2" class="data row6 col2" >64</td>
#       <td id="T_eaecf_row6_col3" class="data row6 col3" >0.953326</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eaecf_row7_col0" class="data row7 col0" >64</td>
#       <td id="T_eaecf_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_eaecf_row7_col2" class="data row7 col2" >128</td>
#       <td id="T_eaecf_row7_col3" class="data row7 col3" >0.967084</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eaecf_row8_col0" class="data row8 col0" >64</td>
#       <td id="T_eaecf_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_eaecf_row8_col2" class="data row8 col2" >64</td>
#       <td id="T_eaecf_row8_col3" class="data row8 col3" >0.959523</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eaecf_row9_col0" class="data row9 col0" >64</td>
#       <td id="T_eaecf_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_eaecf_row9_col2" class="data row9 col2" >128</td>
#       <td id="T_eaecf_row9_col3" class="data row9 col3" >0.975798</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eaecf_row10_col0" class="data row10 col0" >64</td>
#       <td id="T_eaecf_row10_col1" class="data row10 col1" >15</td>
#       <td id="T_eaecf_row10_col2" class="data row10 col2" >64</td>
#       <td id="T_eaecf_row10_col3" class="data row10 col3" >0.966848</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_eaecf_row11_col0" class="data row11 col0" >64</td>
#       <td id="T_eaecf_row11_col1" class="data row11 col1" >15</td>
#       <td id="T_eaecf_row11_col2" class="data row11 col2" >128</td>
#       <td id="T_eaecf_row11_col3" class="data row11 col3" >0.965527</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_eaecf_row12_col0" class="data row12 col0" >128</td>
#       <td id="T_eaecf_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_eaecf_row12_col2" class="data row12 col2" >64</td>
#       <td id="T_eaecf_row12_col3" class="data row12 col3" >0.970884</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_eaecf_row13_col0" class="data row13 col0" >128</td>
#       <td id="T_eaecf_row13_col1" class="data row13 col1" >5</td>
#       <td id="T_eaecf_row13_col2" class="data row13 col2" >128</td>
#       <td id="T_eaecf_row13_col3" class="data row13 col3" >0.972002</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_eaecf_row14_col0" class="data row14 col0" >128</td>
#       <td id="T_eaecf_row14_col1" class="data row14 col1" >10</td>
#       <td id="T_eaecf_row14_col2" class="data row14 col2" >64</td>
#       <td id="T_eaecf_row14_col3" class="data row14 col3" >0.972971</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_eaecf_row15_col0" class="data row15 col0" >128</td>
#       <td id="T_eaecf_row15_col1" class="data row15 col1" >10</td>
#       <td id="T_eaecf_row15_col2" class="data row15 col2" >128</td>
#       <td id="T_eaecf_row15_col3" class="data row15 col3" >0.957428</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_eaecf_row16_col0" class="data row16 col0" >128</td>
#       <td id="T_eaecf_row16_col1" class="data row16 col1" >15</td>
#       <td id="T_eaecf_row16_col2" class="data row16 col2" >64</td>
#       <td id="T_eaecf_row16_col3" class="data row16 col3" >0.965801</td>
#     </tr>
#     <tr>
#       <th id="T_eaecf_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_eaecf_row17_col0" class="data row17 col0" >128</td>
#       <td id="T_eaecf_row17_col1" class="data row17 col1" >15</td>
#       <td id="T_eaecf_row17_col2" class="data row17 col2" >128</td>
#       <td id="T_eaecf_row17_col3" class="data row17 col3" >0.978011</td>
#     </tr>
#   </tbody>
# </table>

# %%
import plotly.graph_objs as go
# Create a meshgrid for the three parameters
param_batch_size = grid_result.cv_results_['param_batch_size'].data
param_epochs = grid_result.cv_results_['param_epochs'].data
param_n_neurons = grid_result.cv_results_['param_n_neurons'].data
performance_scores = grid_result.cv_results_['mean_test_score']
# param1, param2, param3 = np.meshgrid(param_batch_size, param_epochs, param_n_neurons)
param1, param2, param3 = param_batch_size, param_epochs, param_n_neurons

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with color representing performance
scatter = ax.scatter(param1, param2, param3, c=performance_scores, cmap='viridis')
fig.colorbar(scatter, label='persistNSE Score')

# Set labels and title
ax.set_xlabel('batch_size')
ax.set_xticks([32, 64, 128])
ax.set_ylabel('epochs')
ax.set_yticks([5, 10, 15])
ax.set_zlabel('n_neurons')
ax.set_zticks([64, 128])
ax.set_title('Grid Search Results')

# Show the plot
plt.show()

# %% [markdown]
# ### Running Model After Hyperparameter Optimization

# %%
# Best hyperparameters
epochs_best_lstm = 15
n_neurons_best_lstm = 128
batch_size_best_lstm = 128

# %%
# number of lag hours
n_hours = l * sequences_per_hour
reframed, scaler = prepare_data(df_flow_rain_merged, n_hours)

# number of total features
n_features = len(df_flow_rain_merged.columns)

# drop columns of reframed that are not for prediction
n_cols_reframed = len(reframed.columns)
reframed.drop(reframed.columns[n_cols_reframed-n_features+1:], axis=1, inplace=True)

# split into train and test sets
n_train_sequences = n_train_years * DAYS_PER_YEAR * HOURS_PER_DAY * sequences_per_hour
train_X, train_y, test_X, test_y = split_train_and_test(reframed, n_train_sequences, n_hours, n_features)

# %%
# prepare creating model
metrics = [persistent_nse_tensor, nse_tensor]
create_model = build_model(train_X, nse_star, metrics, LSTM)

model = create_model(n_neurons_best_lstm)
history = model.fit(train_X, train_y, epochs=epochs_best_lstm, batch_size=batch_size_best_lstm, validation_split=validation_split, verbose=2, shuffle=False)
# Out:
# Epoch 1/15
# 822/822 - 6s - loss: 7.9577e-04 - persistent_nse_tensor: 0.6131 - nse_tensor: 0.9999 - val_loss: 5.9502e-04 - val_persistent_nse_tensor: 0.7150 - val_nse_tensor: 0.9999 - 6s/epoch - 7ms/step
# Epoch 2/15
# 822/822 - 3s - loss: 1.4356e-04 - persistent_nse_tensor: 0.9566 - nse_tensor: 1.0000 - val_loss: 1.1333e-04 - val_persistent_nse_tensor: 0.9464 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/15
# 822/822 - 3s - loss: 1.5357e-04 - persistent_nse_tensor: 0.9579 - nse_tensor: 1.0000 - val_loss: 7.6639e-04 - val_persistent_nse_tensor: 0.6424 - val_nse_tensor: 0.9999 - 3s/epoch - 4ms/step
# Epoch 4/15
# 822/822 - 3s - loss: 2.0520e-04 - persistent_nse_tensor: 0.9306 - nse_tensor: 1.0000 - val_loss: 9.9803e-05 - val_persistent_nse_tensor: 0.9526 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/15
# 822/822 - 3s - loss: 8.9513e-05 - persistent_nse_tensor: 0.9838 - nse_tensor: 1.0000 - val_loss: 1.9297e-04 - val_persistent_nse_tensor: 0.9122 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 6/15
# 822/822 - 3s - loss: 7.0147e-05 - persistent_nse_tensor: 0.9870 - nse_tensor: 1.0000 - val_loss: 1.4466e-04 - val_persistent_nse_tensor: 0.9319 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 7/15
# 822/822 - 3s - loss: 8.4814e-05 - persistent_nse_tensor: 0.9827 - nse_tensor: 1.0000 - val_loss: 1.4851e-04 - val_persistent_nse_tensor: 0.9356 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 8/15
# 822/822 - 3s - loss: 7.4864e-05 - persistent_nse_tensor: 0.9878 - nse_tensor: 1.0000 - val_loss: 1.2513e-04 - val_persistent_nse_tensor: 0.9383 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 9/15
# 822/822 - 3s - loss: 1.0948e-04 - persistent_nse_tensor: 0.9714 - nse_tensor: 1.0000 - val_loss: 4.6006e-04 - val_persistent_nse_tensor: 0.7963 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 10/15
# 822/822 - 3s - loss: 1.0858e-04 - persistent_nse_tensor: 0.9786 - nse_tensor: 1.0000 - val_loss: 1.3860e-04 - val_persistent_nse_tensor: 0.9311 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 11/15
# 822/822 - 3s - loss: 6.4236e-05 - persistent_nse_tensor: 0.9898 - nse_tensor: 1.0000 - val_loss: 1.2291e-04 - val_persistent_nse_tensor: 0.9426 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 12/15
# 822/822 - 3s - loss: 1.0391e-04 - persistent_nse_tensor: 0.9724 - nse_tensor: 1.0000 - val_loss: 3.2185e-04 - val_persistent_nse_tensor: 0.8634 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 13/15
# 822/822 - 3s - loss: 8.3832e-05 - persistent_nse_tensor: 0.9863 - nse_tensor: 1.0000 - val_loss: 1.0110e-04 - val_persistent_nse_tensor: 0.9461 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 14/15
# 822/822 - 3s - loss: 7.4329e-05 - persistent_nse_tensor: 0.9845 - nse_tensor: 1.0000 - val_loss: 2.1989e-04 - val_persistent_nse_tensor: 0.8990 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 15/15
# 822/822 - 3s - loss: 8.1307e-05 - persistent_nse_tensor: 0.9875 - nse_tensor: 1.0000 - val_loss: 7.6774e-05 - val_persistent_nse_tensor: 0.9657 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step

# %%
plot_history(epochs_best_lstm, history, gauge_name)

# %%
time_test = list(df_flow_rain_merged.reset_index(inplace=False).iloc[n_train_sequences+n_hours:, 0].astype('str'))
plot_predicted_vs_observed(model, scaler, test_X, test_y, n_hours, n_features, mean, time_test, gauge_name)
# Out:
# 1525/1525 [==============================] - 3s 2ms/step
# Test NSE: 0.982
# Test PersistentNSE: 0.981

# %%
persist_nse_with_precipitation_opt_lstm = history.history['val_persistent_nse_tensor']

# %%
plt.plot(persist_nse_with_precipitation_opt_lstm, c='green')
plt.title('LSTM with precipitation - after Grid Search')
plt.xticks(np.arange(epochs_best_lstm), np.arange(1, epochs_best_lstm+1))
plt.xlabel('epoch')
plt.ylabel('persistNSE')
plt.show()

# %% [markdown]
# ## GRU model with rainfall data

# %% [markdown]
# ### Training and Validation

# %%
# number of lag hours
n_hours = l * sequences_per_hour
reframed, scaler = prepare_data(df_flow_rain_merged, n_hours)

# number of total features
n_features = len(df_flow_rain_merged.columns)

# drop columns of reframed that are not for prediction
n_cols_reframed = len(reframed.columns)
reframed.drop(reframed.columns[n_cols_reframed-n_features+1:], axis=1, inplace=True)

print(reframed.head())

# split into train and test sets
n_train_sequences = n_train_years * DAYS_PER_YEAR * HOURS_PER_DAY * sequences_per_hour
train_X, train_y, test_X, test_y = split_train_and_test(reframed, n_train_sequences, n_hours, n_features)
# Out:
#     var1(t-18)  var2(t-18)  var3(t-18)  var4(t-18)  var5(t-18)  var1(t-17)  \
# 18    0.000244    0.757353         0.0         0.0         0.0    0.000244
# 19    0.000244    0.757353         0.0         0.0         0.0    0.000244
# 20    0.000244    0.757353         0.0         0.0         0.0    0.000244
# 21    0.000244    0.757353         0.0         0.0         0.0    0.000244
# 22    0.000244    0.757353         0.0         0.0         0.0    0.000244
#
#     var2(t-17)  var3(t-17)  var4(t-17)  var5(t-17)  ...  var2(t-2)  var3(t-2)  \
# 18    0.757353         0.0         0.0         0.0  ...   0.757843   0.000000
# 19    0.757353         0.0         0.0         0.0  ...   0.758088   0.000000
# 20    0.757353         0.0         0.0         0.0  ...   0.758333   0.000000
# 21    0.757353         0.0         0.0         0.0  ...   0.758578   0.000000
# 22    0.757353         0.0         0.0         0.0  ...   0.758824   0.016393
#
#     var4(t-2)  var5(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  \
# 18        0.0        0.0   0.000433   0.758088   0.000000        0.0
# 19        0.0        0.0   0.000496   0.758333   0.000000        0.0
# 20        0.0        0.0   0.000559   0.758578   0.000000        0.0
# 21        0.0        0.0   0.000621   0.758824   0.016393        0.0
# 22        0.0        0.0   0.000684   0.759069   0.008197        0.0
#
#     var5(t-1)   var1(t)
# 18        0.0  0.000496
# 19        0.0  0.000559
# 20        0.0  0.000621
# 21        0.0  0.000684
# 22        0.0  0.000747
#
# [5 rows x 91 columns]

# %%
# prepare creating model
metrics = [persistent_nse_tensor, nse_tensor]
create_model = build_model(train_X, nse_star, metrics, GRU)

# run model
model = create_model()
history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, validation_split=validation_split, verbose=2, shuffle=False)
# Out:
# Epoch 1/5
# 822/822 - 6s - loss: 8.5259e-04 - persistent_nse_tensor: 0.5553 - nse_tensor: 0.9999 - val_loss: 2.7144e-04 - val_persistent_nse_tensor: 0.8723 - val_nse_tensor: 1.0000 - 6s/epoch - 8ms/step
# Epoch 2/5
# 822/822 - 3s - loss: 1.3333e-04 - persistent_nse_tensor: 0.9643 - nse_tensor: 1.0000 - val_loss: 3.4149e-05 - val_persistent_nse_tensor: 0.9899 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 822/822 - 3s - loss: 9.0896e-05 - persistent_nse_tensor: 0.9825 - nse_tensor: 1.0000 - val_loss: 1.2588e-04 - val_persistent_nse_tensor: 0.9422 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 4/5
# 822/822 - 3s - loss: 9.4883e-05 - persistent_nse_tensor: 0.9753 - nse_tensor: 1.0000 - val_loss: 2.9366e-04 - val_persistent_nse_tensor: 0.8477 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 822/822 - 3s - loss: 8.3993e-05 - persistent_nse_tensor: 0.9786 - nse_tensor: 1.0000 - val_loss: 1.2948e-04 - val_persistent_nse_tensor: 0.9414 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step

# %%
plot_history(epochs, history, gauge_name)

# %%
time_test = list(df_flow_rain_merged.reset_index(inplace=False).iloc[n_train_sequences+n_hours:, 0].astype('str'))
plot_predicted_vs_observed(model, scaler, test_X, test_y, n_hours, n_features, mean, time_test, gauge_name)
# Out:
# 1525/1525 [==============================] - 3s 2ms/step
# Test NSE: 0.972
# Test PersistentNSE: 0.971

# %%
persist_nse_with_precipitation_gru = history.history['val_persistent_nse_tensor']

# %%
plt.plot(persist_nse_with_precipitation_gru, c='magenta')
plt.title('GRU with precipitation')
plt.xticks(np.arange(epochs), np.arange(1, epochs+1))
plt.xlabel('epoch')
plt.ylabel('score')
plt.show()

# %% [markdown]
# ### Hyperparameter Optimization

# %%
model = KerasRegressor(build_fn=create_model, n_neurons=128)

# %%
from keras.src.layers.serialization import activation
param_grid = dict(epochs=[5, 10, 15], batch_size=[32, 64, 128], n_neurons=[64, 128])
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=make_scorer(persistent_nse_numpy), n_jobs=-1, cv=3, verbose=2)
grid_result = grid.fit(train_X, train_y)
print("Done grid search")
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Epoch 1/5
# 1232/1232 [==============================] - 6s 3ms/step - loss: 1.5739e-04 - persistent_nse_tensor: 0.9604 - nse_tensor: 1.0000
# Epoch 2/5
# 1232/1232 [==============================] - 4s 3ms/step - loss: 8.8478e-05 - persistent_nse_tensor: 0.9776 - nse_tensor: 1.0000
# Epoch 3/5
# 1232/1232 [==============================] - 4s 3ms/step - loss: 7.2763e-05 - persistent_nse_tensor: 0.9819 - nse_tensor: 1.0000
# Epoch 4/5
# 1232/1232 [==============================] - 4s 3ms/step - loss: 5.7622e-05 - persistent_nse_tensor: 0.9849 - nse_tensor: 1.0000
# Epoch 5/5
# 1232/1232 [==============================] - 4s 3ms/step - loss: 4.1990e-05 - persistent_nse_tensor: 0.9886 - nse_tensor: 1.0000
# Done grid search

# %%
print("Best: test score %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for m, s, param in zip(means, stds, params):
    print("mean test score %f (std test score %f) with: %r" % (m, s, param))
# Out:
# Best: test score 0.972184 using {'batch_size': 128, 'epochs': 5, 'n_neurons': 128}
# mean test score 0.966920 (std test score 0.008209) with: {'batch_size': 32, 'epochs': 5, 'n_neurons': 64}
# mean test score 0.962891 (std test score 0.013808) with: {'batch_size': 32, 'epochs': 5, 'n_neurons': 128}
# mean test score 0.966519 (std test score 0.010245) with: {'batch_size': 32, 'epochs': 10, 'n_neurons': 64}
# mean test score 0.954443 (std test score 0.014419) with: {'batch_size': 32, 'epochs': 10, 'n_neurons': 128}
# mean test score 0.960806 (std test score 0.014422) with: {'batch_size': 32, 'epochs': 15, 'n_neurons': 64}
# mean test score 0.956999 (std test score 0.007245) with: {'batch_size': 32, 'epochs': 15, 'n_neurons': 128}
# mean test score 0.939661 (std test score 0.035929) with: {'batch_size': 64, 'epochs': 5, 'n_neurons': 64}
# mean test score 0.908402 (std test score 0.078687) with: {'batch_size': 64, 'epochs': 5, 'n_neurons': 128}
# mean test score 0.967208 (std test score 0.010397) with: {'batch_size': 64, 'epochs': 10, 'n_neurons': 64}
# mean test score 0.963478 (std test score 0.004766) with: {'batch_size': 64, 'epochs': 10, 'n_neurons': 128}
# mean test score 0.952963 (std test score 0.020661) with: {'batch_size': 64, 'epochs': 15, 'n_neurons': 64}
# mean test score 0.949652 (std test score 0.010623) with: {'batch_size': 64, 'epochs': 15, 'n_neurons': 128}
# mean test score 0.933005 (std test score 0.045000) with: {'batch_size': 128, 'epochs': 5, 'n_neurons': 64}
# mean test score 0.972184 (std test score 0.009329) with: {'batch_size': 128, 'epochs': 5, 'n_neurons': 128}
# mean test score 0.963321 (std test score 0.023454) with: {'batch_size': 128, 'epochs': 10, 'n_neurons': 64}
# mean test score 0.959662 (std test score 0.013863) with: {'batch_size': 128, 'epochs': 10, 'n_neurons': 128}
# mean test score 0.941667 (std test score 0.037063) with: {'batch_size': 128, 'epochs': 15, 'n_neurons': 64}
# mean test score 0.938880 (std test score 0.034688) with: {'batch_size': 128, 'epochs': 15, 'n_neurons': 128}

# %%
def highlight_max_row(data):
    """Highlight the entire row if mean_test_score is the maximum."""
    max_score = data['mean_test_score'].max()
    highlight = ['background-color: yellow' if val == max_score else '' for val in data['mean_test_score']]
    return pd.DataFrame([highlight for _ in data.columns], index=data.columns).T

# %%
df_grid = pd.DataFrame({
    'param_batch_size': grid_result.cv_results_['param_batch_size'].data,
    'param_epochs': grid_result.cv_results_['param_epochs'].data,
    'param_n_neurons': grid_result.cv_results_['param_n_neurons'].data,
    'mean_test_score': grid_result.cv_results_['mean_test_score']
})

df_grid.style.apply(highlight_max_row, axis=None)
# Out:
# <style type="text/css">
# #T_e2db7_row13_col0, #T_e2db7_row13_col1, #T_e2db7_row13_col2, #T_e2db7_row13_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e2db7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2db7_level0_col0" class="col_heading level0 col0" >param_batch_size</th>
#       <th id="T_e2db7_level0_col1" class="col_heading level0 col1" >param_epochs</th>
#       <th id="T_e2db7_level0_col2" class="col_heading level0 col2" >param_n_neurons</th>
#       <th id="T_e2db7_level0_col3" class="col_heading level0 col3" >mean_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2db7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2db7_row0_col0" class="data row0 col0" >32</td>
#       <td id="T_e2db7_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_e2db7_row0_col2" class="data row0 col2" >64</td>
#       <td id="T_e2db7_row0_col3" class="data row0 col3" >0.966920</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2db7_row1_col0" class="data row1 col0" >32</td>
#       <td id="T_e2db7_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_e2db7_row1_col2" class="data row1 col2" >128</td>
#       <td id="T_e2db7_row1_col3" class="data row1 col3" >0.962891</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e2db7_row2_col0" class="data row2 col0" >32</td>
#       <td id="T_e2db7_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_e2db7_row2_col2" class="data row2 col2" >64</td>
#       <td id="T_e2db7_row2_col3" class="data row2 col3" >0.966519</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e2db7_row3_col0" class="data row3 col0" >32</td>
#       <td id="T_e2db7_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_e2db7_row3_col2" class="data row3 col2" >128</td>
#       <td id="T_e2db7_row3_col3" class="data row3 col3" >0.954443</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e2db7_row4_col0" class="data row4 col0" >32</td>
#       <td id="T_e2db7_row4_col1" class="data row4 col1" >15</td>
#       <td id="T_e2db7_row4_col2" class="data row4 col2" >64</td>
#       <td id="T_e2db7_row4_col3" class="data row4 col3" >0.960806</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e2db7_row5_col0" class="data row5 col0" >32</td>
#       <td id="T_e2db7_row5_col1" class="data row5 col1" >15</td>
#       <td id="T_e2db7_row5_col2" class="data row5 col2" >128</td>
#       <td id="T_e2db7_row5_col3" class="data row5 col3" >0.956999</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e2db7_row6_col0" class="data row6 col0" >64</td>
#       <td id="T_e2db7_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_e2db7_row6_col2" class="data row6 col2" >64</td>
#       <td id="T_e2db7_row6_col3" class="data row6 col3" >0.939661</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e2db7_row7_col0" class="data row7 col0" >64</td>
#       <td id="T_e2db7_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_e2db7_row7_col2" class="data row7 col2" >128</td>
#       <td id="T_e2db7_row7_col3" class="data row7 col3" >0.908402</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e2db7_row8_col0" class="data row8 col0" >64</td>
#       <td id="T_e2db7_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_e2db7_row8_col2" class="data row8 col2" >64</td>
#       <td id="T_e2db7_row8_col3" class="data row8 col3" >0.967208</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e2db7_row9_col0" class="data row9 col0" >64</td>
#       <td id="T_e2db7_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_e2db7_row9_col2" class="data row9 col2" >128</td>
#       <td id="T_e2db7_row9_col3" class="data row9 col3" >0.963478</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e2db7_row10_col0" class="data row10 col0" >64</td>
#       <td id="T_e2db7_row10_col1" class="data row10 col1" >15</td>
#       <td id="T_e2db7_row10_col2" class="data row10 col2" >64</td>
#       <td id="T_e2db7_row10_col3" class="data row10 col3" >0.952963</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e2db7_row11_col0" class="data row11 col0" >64</td>
#       <td id="T_e2db7_row11_col1" class="data row11 col1" >15</td>
#       <td id="T_e2db7_row11_col2" class="data row11 col2" >128</td>
#       <td id="T_e2db7_row11_col3" class="data row11 col3" >0.949652</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e2db7_row12_col0" class="data row12 col0" >128</td>
#       <td id="T_e2db7_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_e2db7_row12_col2" class="data row12 col2" >64</td>
#       <td id="T_e2db7_row12_col3" class="data row12 col3" >0.933005</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e2db7_row13_col0" class="data row13 col0" >128</td>
#       <td id="T_e2db7_row13_col1" class="data row13 col1" >5</td>
#       <td id="T_e2db7_row13_col2" class="data row13 col2" >128</td>
#       <td id="T_e2db7_row13_col3" class="data row13 col3" >0.972184</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e2db7_row14_col0" class="data row14 col0" >128</td>
#       <td id="T_e2db7_row14_col1" class="data row14 col1" >10</td>
#       <td id="T_e2db7_row14_col2" class="data row14 col2" >64</td>
#       <td id="T_e2db7_row14_col3" class="data row14 col3" >0.963321</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e2db7_row15_col0" class="data row15 col0" >128</td>
#       <td id="T_e2db7_row15_col1" class="data row15 col1" >10</td>
#       <td id="T_e2db7_row15_col2" class="data row15 col2" >128</td>
#       <td id="T_e2db7_row15_col3" class="data row15 col3" >0.959662</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e2db7_row16_col0" class="data row16 col0" >128</td>
#       <td id="T_e2db7_row16_col1" class="data row16 col1" >15</td>
#       <td id="T_e2db7_row16_col2" class="data row16 col2" >64</td>
#       <td id="T_e2db7_row16_col3" class="data row16 col3" >0.941667</td>
#     </tr>
#     <tr>
#       <th id="T_e2db7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e2db7_row17_col0" class="data row17 col0" >128</td>
#       <td id="T_e2db7_row17_col1" class="data row17 col1" >15</td>
#       <td id="T_e2db7_row17_col2" class="data row17 col2" >128</td>
#       <td id="T_e2db7_row17_col3" class="data row17 col3" >0.938880</td>
#     </tr>
#   </tbody>
# </table>

# %%
import plotly.graph_objs as go
# Create a meshgrid for the three parameters
param_batch_size = grid_result.cv_results_['param_batch_size'].data
param_epochs = grid_result.cv_results_['param_epochs'].data
param_n_neurons = grid_result.cv_results_['param_n_neurons'].data
performance_scores = grid_result.cv_results_['mean_test_score']
# param1, param2, param3 = np.meshgrid(param_batch_size, param_epochs, param_n_neurons)
param1, param2, param3 = param_batch_size, param_epochs, param_n_neurons

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with color representing performance
scatter = ax.scatter(param1, param2, param3, c=performance_scores, cmap='viridis')
fig.colorbar(scatter, label='persistNSE Score')

# Set labels and title
ax.set_xlabel('batch_size')
ax.set_xticks([32, 64, 128])
ax.set_ylabel('epochs')
ax.set_yticks([5, 10, 15])
ax.set_zlabel('n_neurons')
ax.set_zticks([64, 128])
ax.set_title('Grid Search Results')

# Show the plot
plt.show()

# %% [markdown]
# ### Running Model After Hyperparameter Optimization

# %%
# Best hyperparameters
epochs_best_gru = 5
n_neurons_best_gru = 128
batch_size_best_gru = 128

# %%
# number of lag hours
n_hours = l * sequences_per_hour
reframed, scaler = prepare_data(df_flow_rain_merged, n_hours)

# number of total features
n_features = len(df_flow_rain_merged.columns)

# drop columns of reframed that are not for prediction
n_cols_reframed = len(reframed.columns)
reframed.drop(reframed.columns[n_cols_reframed-n_features+1:], axis=1, inplace=True)

# split into train and test sets
n_train_sequences = n_train_years * DAYS_PER_YEAR * HOURS_PER_DAY * sequences_per_hour
train_X, train_y, test_X, test_y = split_train_and_test(reframed, n_train_sequences, n_hours, n_features)

# %%
# prepare creating model
metrics = [persistent_nse_tensor, nse_tensor]
create_model = build_model(train_X, nse_star, metrics, GRU)

model = create_model(n_neurons_best_gru)
history = model.fit(train_X, train_y, epochs=epochs_best_gru, batch_size=batch_size_best_gru, validation_split=validation_split, verbose=2, shuffle=False)
# Out:
# Epoch 1/5
# 822/822 - 6s - loss: 0.0011 - persistent_nse_tensor: 0.3988 - nse_tensor: 0.9999 - val_loss: 6.9522e-04 - val_persistent_nse_tensor: 0.6719 - val_nse_tensor: 0.9999 - 6s/epoch - 7ms/step
# Epoch 2/5
# 822/822 - 3s - loss: 2.4791e-04 - persistent_nse_tensor: 0.8958 - nse_tensor: 1.0000 - val_loss: 5.5952e-05 - val_persistent_nse_tensor: 0.9765 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 3/5
# 822/822 - 3s - loss: 8.8639e-05 - persistent_nse_tensor: 0.9855 - nse_tensor: 1.0000 - val_loss: 1.2816e-04 - val_persistent_nse_tensor: 0.9344 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 4/5
# 822/822 - 3s - loss: 9.2904e-05 - persistent_nse_tensor: 0.9754 - nse_tensor: 1.0000 - val_loss: 3.2219e-04 - val_persistent_nse_tensor: 0.8241 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step
# Epoch 5/5
# 822/822 - 3s - loss: 8.5164e-05 - persistent_nse_tensor: 0.9788 - nse_tensor: 1.0000 - val_loss: 2.0478e-04 - val_persistent_nse_tensor: 0.8907 - val_nse_tensor: 1.0000 - 3s/epoch - 4ms/step

# %%
plot_history(epochs_best_gru, history, gauge_name)

# %%
time_test = list(df_flow_rain_merged.reset_index(inplace=False).iloc[n_train_sequences+n_hours:, 0].astype('str'))
plot_predicted_vs_observed(model, scaler, test_X, test_y, n_hours, n_features, mean, time_test, gauge_name)
# Out:
# 1525/1525 [==============================] - 3s 2ms/step
# Test NSE: 0.934
# Test PersistentNSE: 0.933

# %%
persist_nse_with_precipitation_opt_gru = history.history['val_persistent_nse_tensor']

# %%
plt.plot(persist_nse_with_precipitation_opt_gru, c='magenta')
plt.title('GRU with precipitation - after Grid Search')
plt.xticks(np.arange(epochs_best_gru), np.arange(1, epochs_best_gru+1))
plt.xlabel('epoch')
plt.ylabel('persistNSE')
plt.show()

# %% [markdown]
# ## LSTM VS GRU

# %%
plt.plot(persist_nse_with_precipitation_opt_lstm, label='LSTM', c='green')
plt.plot(persist_nse_with_precipitation_opt_gru, label='GRU', c='magenta')
plt.title('LSTM VS GRU')
epochs_max = max(epochs_best_lstm, epochs_best_gru)
plt.xticks(np.arange(epochs_max), np.arange(1, epochs_max + 1))
plt.ylim(0, 1)
plt.xlabel('epoch')
plt.ylabel('persistNSE')
plt.legend()
plt.show()
